# %% [markdown]
# <a href="https://colab.research.google.com/github/Shamima21/CancerGeneIdentification/blob/main/Gene%20Selection%20/src/Co_relation_graph_in_R_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Leukemia
install.packages("ggplot2")
library(ggplot2)


attributes <- c("STXBP2", "LY75-CD302", "SMARCA4", "MCM3", "IL18", "VPREB1", "CSTA", "LYZ", "SNRPN", "SPTAN1",
                "SERPINA1", "CXCR4", "APLP2", "LAMP2", "ZNF91", "TALDO1", "TSPO", "PCBD1", "CYFIP2", "DNTT",
                "ADA", "PYGL", "ITGB2", "LYN", "LYZ", "MPO", "CTSA", "CD33", "CST3", "CD19", "IL7R", "MYL6B",
                "STMN1", "TCF3", "TIMP2", "CD81", "FAH", "ATP6V0C", "CTSD", "CLU", "IFI16", "LRPAP1", "TCF3",
                "CFP", "CEBPD", "CD19", "CFD", "ACADM", "CCND3", "SERPINB1", "AZU1", "PPP3CC", "ZNF22", "BLK",
                "CD79A", "MAN2B1", "CACNB3", "MLLT11", "AIF1", "MYB", "SMARCA4", "MGST1", "MEF2A", "LTC4S",
                "KYNU", "UBE2V2", "GTF2IP4", "SRPK2", "ISG20", "ANXA1", "PLEK", "ALDOA", "LYZ", "AKR1B1",
                "RNASE2", "SRGN", "EZR", "SPI1", "YWHAQ", "PSMA6", "RHOG", "GRN", "CD63", "ITGB2", "PSMB9",
                "SP3", "RBBP4", "GLRX", "RCN2", "ZYX", "CORO1B", "MYO1F", "CXCL8", "NME4", "NUP88", "TOP2B",
                "RHOH", "POU2AF1", "GNG7", "DAPK1")
correlation_values <- c(0.814, 0.813, 0.791, 0.756, 0.751, 0.743, 0.737, 0.736, 0.733, 0.708,
                        0.706, 0.703, 0.701, 0.7, 0.699, 0.696, 0.691, 0.689, 0.687, 0.684,
                        0.674, 0.674, 0.665, 0.665, 0.664, 0.658, 0.656, 0.655, 0.65, 0.649,
                        0.644, 0.64, 0.639, 0.639, 0.638, 0.637, 0.636, 0.632, 0.628, 0.627,
                        0.625, 0.618, 0.617, 0.613, 0.61, 0.608, 0.606, 0.604, 0.604, 0.601,
                        0.599, 0.599, 0.599, 0.598, 0.595, 0.594, 0.594, 0.592, 0.591, 0.589,
                        0.588, 0.587, 0.587, 0.585, 0.584, 0.583, 0.582, 0.58, 0.579, 0.578,
                        0.578, 0.576, 0.575, 0.575, 0.574, 0.573, 0.571, 0.57, 0.569, 0.568,
                        0.566, 0.565, 0.563, 0.562, 0.562, 0.561, 0.558, 0.558, 0.558, 0.557,
                        0.556, 0.555, 0.555, 0.555, 0.555, 0.554, 0.554, 0.553, 0.552, 0.551)

# Create a DataFrame
df_pair <- data.frame(Attributes = attributes[1:100], Rank = 1:100, Correlation_Values = correlation_values[1:100])

# Load required libraries
library(ggplot2)

# Format attribute names (replace underscores with spaces)
df_pair$Attributes <- gsub("_", " ", df_pair$Attributes)

# Using ggplot for pair plot
ggplot(df_pair, aes(x = Rank, y = Correlation_Values, color = Attributes)) +
  geom_point() +
  ggtitle("Top 100 Attribute Correlation ") +
  theme_minimal()
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# plot without title

# %%
#leukemia
library(ggplot2)
# Attributes and correlation values
attributes <- c("STXBP2", "LY75-CD302", "SMARCA4", "MCM3", "IL18", "VPREB1", "CSTA", "LYZ", "SNRPN", "SPTAN1",
                "SERPINA1", "CXCR4", "APLP2", "LAMP2", "ZNF91", "TALDO1", "TSPO", "PCBD1", "CYFIP2", "DNTT",
                "ADA", "PYGL", "ITGB2", "LYN", "LYZ", "MPO", "CTSA", "CD33", "CST3", "CD19", "IL7R", "MYL6B",
                "STMN1", "TCF3", "TIMP2", "CD81", "FAH", "ATP6V0C", "CTSD", "CLU", "IFI16", "LRPAP1", "TCF3",
                "CFP", "CEBPD", "CD19", "CFD", "ACADM", "CCND3", "SERPINB1", "AZU1", "PPP3CC", "ZNF22", "BLK",
                "CD79A", "MAN2B1", "CACNB3", "MLLT11", "AIF1", "MYB", "SMARCA4", "MGST1", "MEF2A", "LTC4S",
                "KYNU", "UBE2V2", "GTF2IP4", "SRPK2", "ISG20", "ANXA1", "PLEK", "ALDOA", "LYZ", "AKR1B1",
                "RNASE2", "SRGN", "EZR", "SPI1", "YWHAQ", "PSMA6", "RHOG", "GRN", "CD63", "ITGB2", "PSMB9",
                "SP3", "RBBP4", "GLRX", "RCN2", "ZYX", "CORO1B", "MYO1F", "CXCL8", "NME4", "NUP88", "TOP2B",
                "RHOH", "POU2AF1", "GNG7", "DAPK1")
correlation_values <- c(0.814, 0.813, 0.791, 0.756, 0.751, 0.743, 0.737, 0.736, 0.733, 0.708,
                        0.706, 0.703, 0.701, 0.7, 0.699, 0.696, 0.691, 0.689, 0.687, 0.684,
                        0.674, 0.674, 0.665, 0.665, 0.664, 0.658, 0.656, 0.655, 0.65, 0.649,
                        0.644, 0.64, 0.639, 0.639, 0.638, 0.637, 0.636, 0.632, 0.628, 0.627,
                        0.625, 0.618, 0.617, 0.613, 0.61, 0.608, 0.606, 0.604, 0.604, 0.601,
                        0.599, 0.599, 0.599, 0.598, 0.595, 0.594, 0.594, 0.592, 0.591, 0.589,
                        0.588, 0.587, 0.587, 0.585, 0.584, 0.583, 0.582, 0.58, 0.579, 0.578,
                        0.578, 0.576, 0.575, 0.575, 0.574, 0.573, 0.571, 0.57, 0.569, 0.568,
                        0.566, 0.565, 0.563, 0.562, 0.562, 0.561, 0.558, 0.558, 0.558, 0.557,
                        0.556, 0.555, 0.555, 0.555, 0.555, 0.554, 0.554, 0.553, 0.552, 0.551)

# Create a DataFrame
df_pair <- data.frame(Attributes = attributes[1:100], Rank = 1:100, Correlation_Values = correlation_values[1:100])

# Format attribute names (replace underscores with spaces)
df_pair$Attributes <- gsub("_", " ", df_pair$Attributes)

# Using ggplot for pair plot
p <- ggplot(df_pair, aes(x = Rank, y = Correlation_Values, color = Attributes)) +
  geom_point() +
  ggtitle("Top 100 Attribute Correlation for Leukemia") +
  theme_minimal() +
  theme(plot.title = element_text(hjust = 0.5))

# Save the plot with a wider aspect ratio
ggsave("wide_plot leukemia.pdf", p, width = 10, height = 6)

# %%
library(ggplot2)

# Attributes and correlation values for Lymphoma
attributes_lymphoma <- c("CTPS1", "ESPL1", "EIF4EP1", "M6PR", "GPS2", "BYSL", "KIF2C", "NME1", "LDHA", "CDKN3",
                         "MTHFD1", "MCM2", "GM2A", "PRDX6", "IDH2", "EIF2S1", "MIF", "ENO1", "HMGA1", "FIM3",
                         "H2AX", "UBE2C", "CCNB1", "MYBL2", "CCT3", "MT1G", "MCM6", "KIF11", "SRM", "GINS1",
                         "MCM7", "ADA", "CHAF1A", "PNP", "MKI67", "CDK1", "KPNA2", "PRDX1", "VDAC1", "PKM",
                         "CKAP5", "TRAP1", "EIF3B", "SNRPB", "WARS1", "PIM1", "HMBS", "PDHA1", "CTSD", "PSMB2",
                         "IMPDH2", "POLD2", "ATIC", "MT2A", "TYMS", "PSME2", "HSP90AB1", "CENPA", "FCGR1A",
                         "CCT5", "STMN1", "LGALS3", "MCM5", "MCM3", "TK1", "CDK2", "TFRC", "CAD", "CCNE1",
                         "EBP", "THOP1", "BCL2A1", "PCCB", "GPNMB", "AARS1", "MCM3", "ART1", "CDC20", "SSRP1",
                         "GLUL", "TALDO1", "PSMA4", "HSPA5", "ATP5MC1", "NUP93", "ESA4", "CCNF", "LDHB",
                         "DTYMK", "COX5A", "PSMC3", "PSMB7", "TSFM", "HSPD1", "LOC105372824", "SEC61B", "CDK4",
                         "CCR1", "ADCY4", "GCN1")
correlation_values_lymphoma <- c(0.69, 0.684, 0.679, 0.679, 0.675, 0.662, 0.662, 0.66, 0.655, 0.649,
                                 0.645, 0.642, 0.642, 0.635, 0.633, 0.632, 0.63, 0.627, 0.625, 0.621,
                                 0.62, 0.617, 0.616, 0.614, 0.614, 0.612, 0.611, 0.61, 0.609, 0.608,
                                 0.607, 0.607, 0.607, 0.606, 0.605, 0.603, 0.602, 0.601, 0.6, 0.599,
                                 0.596, 0.594, 0.594, 0.593, 0.591, 0.59, 0.588, 0.586, 0.586, 0.585,
                                 0.585, 0.585, 0.583, 0.58, 0.579, 0.579, 0.579, 0.578, 0.577, 0.576,
                                 0.576, 0.576, 0.576, 0.575, 0.574, 0.573, 0.573, 0.57, 0.57, 0.57,
                                 0.57, 0.567, 0.565, 0.565, 0.564, 0.563, 0.563, 0.562, 0.561, 0.561,
                                 0.56, 0.559, 0.558, 0.557, 0.557, 0.557, 0.557, 0.556, 0.556, 0.556,
                                 0.554, 0.553, 0.553, 0.553, 0.553, 0.551, 0.551, 0.55, 0.55, 0.548)

# Create a DataFrame
df_pair_lymphoma <- data.frame(Attributes = attributes_lymphoma, Rank = 1:length(attributes_lymphoma), Correlation_Values = correlation_values_lymphoma)

# Format attribute names (replace underscores with spaces)
df_pair_lymphoma$Attributes <- gsub("_", " ", df_pair_lymphoma$Attributes)

# Using ggplot for pair plot
p_lymphoma <- ggplot(df_pair_lymphoma, aes(x = Rank, y = Correlation_Values, color = Attributes)) +
  geom_point() +
  ggtitle("Top Attribute Correlation for Lymphoma") +
  theme_minimal() +
  theme(plot.title = element_text(hjust = 0.5))

# Save the plot with a wider aspect ratio
ggsave("lymphoma_wide_plot.pdf", p_lymphoma, width = 10, height = 6)

# %%
library(ggplot2)

# Attributes and correlation values for Prostate Cancer
attributes_pc <- c("TYMS", "C1QTNF3-AMACR", "NELL2", "VSTM4", "PDLIM5", "TARP", "HSPD1", "XBP1", "DPT", "RBP1",
                   "CFD", "EPCAM", "HPN", "MB", "GGCT", "S100A4", "PTGDS", "GSTM1", "PENK", "MARCKSL1",
                   "LMO3", "FOLH1B", "PTGDS", "RCAN2", "SND1", "ERG", "TMSB15A", "STEAP1", "CLDN4", "TCP1",
                   "KLK3", "FOLH1B", "SMG1P2", "TSPAN1", "SNCG", "RAP1GAP", "SERINC5", "CNPY2", "GADD45G", "TP63",
                   "TSPAN8", "HSPA8", "ACSM1", "NME1", "GPRC5B", "ME1", "HEBP2", "LDHA", "IQGAP2", "GSTM1",
                   "NME2", "NCALD", "PRKCB", "NME2", "PLAGL1", "SLC25A6", "TFF3", "SERPINA3", "G0S2", "LAMB3",
                   "BMP5", "SERPINB5", "THBS4", "XBP1", "SERPINB5", "AKR1A1", "AGR2", "NDUFV2", "CYP1B1", "TUBB2A",
                   "PRDX4", "DPT", "FXYD1", "ODC1", "GDF15", "AMD1", "ALDH1A3", "AMD1", "FBP1", "ENTREP1",
                   "CLDN8", "ZNF593", "HOXB13", "CYB5A", "FMOD", "MPC2", "CLDN3", "AOX1", "SDC3", "SSR2",
                   "SCGB1A1", "AMD1", "TXN", "IGF2", "RUNX1T1", "LOC391322", "ACLY", "MYDGF", "SIM2", "NUPR1", "DNPH1")
correlation_values_pc <- c(0.579, 0.684, 0.562, 0.521, 0.51, 0.5, 0.433, 0.43, 0.425, 0.421,
                           0.417, 0.406, 0.396, 0.386, 0.386, 0.374, 0.374, 0.374, 0.37, 0.365,
                           0.363, 0.354, 0.354, 0.353, 0.353, 0.353, 0.345, 0.345, 0.337, 0.334,
                           0.325, 0.323, 0.323, 0.321, 0.317, 0.316, 0.316, 0.316, 0.315, 0.31,
                           0.308, 0.304, 0.301, 0.301, 0.301, 0.3, 0.299, 0.299, 0.291, 0.291,
                           0.289, 0.289, 0.283, 0.283, 0.282, 0.282, 0.274, 0.274, 0.274, 0.273,
                           0.271, 0.269, 0.265, 0.264, 0.262, 0.254, 0.25, 0.249, 0.245, 0.243,
                           0.238, 0.235, 0.233, 0.233, 0.231, 0.23, 0.226, 0.225, 0.224, 0.218,
                           0.218, 0.218, 0.218, 0.207, 0.206, 0.206, 0.203, 0.203, 0.201, 0.201,
                           0.193, 0.19, 0.19, 0.187, 0.184, 0.184, 0.184, 0.174, 0.172, 0.167, 0.148)


# Create a DataFrame
df_pc <- data.frame(Attributes = attributes_pc,  Rank = 1:length(attributes_pc), Correlation_Values = correlation_values_pc)

# Using ggplot for pair plot
p_pc <- ggplot(df_pc, aes(x = Rank, y = Correlation_Values, color = Attributes)) +
  geom_point() +
  ggtitle("Top 100 Attribute Correlation for Prostate Cancer") +
  theme_minimal() +
  theme(plot.title = element_text(hjust = 0.5))

# Save the plot with a wider aspect ratio
ggsave("wide_plot_prostate_cancer.pdf", p_pc, width = 10, height = 6)
